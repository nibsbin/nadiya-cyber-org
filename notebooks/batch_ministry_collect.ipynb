# %% [markdown]
# # Batch Ministry Workflow
#
# This notebook automates the collection of organization names and cybersecurity responsibility assessments across multiple ministry types.
#
# ## Features
#
# - **Sequential Processing:** Domains processed one at a time to avoid rate limits
# - **Automatic Retry:** Exponential backoff (2s, 4s, 8s, 16s) handles transient failures
# - **Progress Tracking:** See status of each step as it completes
#
# ## Setup
#
# Follow [these instructions](https://docs.astral.sh/uv/getting-started/installation/) to install `uv`. Then run the following command to set up your environment:
#
# ```bash
# uv sync --quiet
# ```

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../").resolve()))

from scripts.batch_ministry_workflow import run_batch_workflow, MinistryWorkflow
from data import DOMAINS, COUNTRIES
import pandas as pd

# %% [markdown]
# ## Configuration
#
# Choose which domains to process:

# %%
# Option 1: Process specific domains
domains_to_process = [
    "Science & Technology",
    "Foreign Affairs",
    "Defense",
    "Education",
]

# Option 2: Process all available domains (uncomment to use)
# domains_to_process = DOMAINS

# Configuration
output_dir = Path("../outputs")
workers = 2  # Number of parallel workers

print(f"Will process {len(domains_to_process)} domains:")
for i, domain in enumerate(domains_to_process, 1):
    print(f"  {i}. {domain}")
print(f"\nOutput directory: {output_dir}")
print(f"Workers: {workers}")
print(f"\nAvailable domains: {', '.join(DOMAINS)}")
# Out:
# Will process 4 domains:
#   1. Science & Technology
#   2. Foreign Affairs
#   3. Defense
#   4. Education
#
# Output directory: ../outputs
# Workers: 2
#
# Available domains: Foreign Affairs, Education, Economy, Finance, Commerce, Transportation, Defense, Energy, Science and Technology (and/or Innovation), Communication, Interior/Domestic Affairs, Justice, Trade, Housing, Health, Labor, Culture, Agriculture, Industry

# %% [markdown]
# ## Run Batch Workflow
#
# This will process all selected domains automatically:

# %%
results = await run_batch_workflow(domains_to_process, output_dir, workers=workers)
# Out:
# ############################################################
# # BATCH MINISTRY WORKFLOW
# # Processing 4 domains SEQUENTIALLY
# # Workers per domain: 2
# # Output directory: ../outputs
# ############################################################
#
# Note: Domains processed one at a time to avoid rate limits.
#
# [1/4] Processing domain: Science & Technology
#
# 🚀 Starting complete workflow for domain: Science & Technology
#
# ============================================================
# STEP 1: Collecting organizations for Science & Technology
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 organizations to ../outputs/science_&_technology/organization_names_science_&_technology.csv
#
# ============================================================
# STEP 2: Assessing cybersecurity responsibility for Science & Technology
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 assessments to ../outputs/science_&_technology/organization_cyber_science_&_technology.xlsx
#
# ✅ Completed workflow for Science & Technology
#    Organizations collected: 193
#    Cybersecurity assessments: 193
#
# [2/4] Processing domain: Foreign Affairs
#
# 🚀 Starting complete workflow for domain: Foreign Affairs
#
# ============================================================
# STEP 1: Collecting organizations for Foreign Affairs
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 organizations to ../outputs/foreign_affairs/organization_names_foreign_affairs.csv
#
# ============================================================
# STEP 2: Assessing cybersecurity responsibility for Foreign Affairs
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 assessments to ../outputs/foreign_affairs/organization_cyber_foreign_affairs.xlsx
#
# ✅ Completed workflow for Foreign Affairs
#    Organizations collected: 193
#    Cybersecurity assessments: 193
#
# [3/4] Processing domain: Defense
#
# 🚀 Starting complete workflow for domain: Defense
#
# ============================================================
# STEP 1: Collecting organizations for Defense
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 organizations to ../outputs/defense/organization_names_defense.csv
#
# ============================================================
# STEP 2: Assessing cybersecurity responsibility for Defense
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 assessments to ../outputs/defense/organization_cyber_defense.xlsx
#
# ✅ Completed workflow for Defense
#    Organizations collected: 193
#    Cybersecurity assessments: 193
#
# [4/4] Processing domain: Education
#
# 🚀 Starting complete workflow for domain: Education
#
# ============================================================
# STEP 1: Collecting organizations for Education
# ============================================================
# 🗑️  Deleted existing database to start fresh
# ✓ Saved 193 organizations to ../outputs/education/organization_names_education.csv
#
# ============================================================
# STEP 2: Assessing cybersecurity responsibility for Education
# ============================================================
# ✓ Saved 193 assessments to ../outputs/education/organization_cyber_education.xlsx
#
# ✅ Completed workflow for Education
#    Organizations collected: 193
#    Cybersecurity assessments: 193
#
# ############################################################
# # BATCH WORKFLOW SUMMARY
# ############################################################
# ✓ Science & Technology: 193 orgs, 193 assessments
# ✓ Foreign Affairs: 193 orgs, 193 assessments
# ✓ Defense: 193 orgs, 193 assessments
# ✓ Education: 193 orgs, 193 assessments

# %% [markdown]
# ## Alternative: Run Single Domain
#
# If you want to run just one domain (useful for testing or re-running failed domains):

# %%
# Run workflow for a single domain
if False:
    single_domain = "" \
    ""

    workflow = MinistryWorkflow(single_domain, output_dir, workers=workers)
    org_df, cyber_df = await workflow.run_complete_workflow()

    print(f"\nResults for {single_domain}:")
    print(f"  Organizations: {len(org_df)}")
    print(f"  Assessments: {len(cyber_df)}")

# %% [markdown]
# ## View Results
#
# Load and inspect results for a specific domain:

# %%
# Choose a domain to view
domain_to_view = "Science & Technology"

# Load organizations
org_file = output_dir / domain_to_view.lower().replace(" ", "_") / f"organization_names_{domain_to_view.lower().replace(' ', '_')}.csv"
if org_file.exists():
    org_df = pd.read_csv(org_file)
    print(f"Organizations for {domain_to_view}:")
    display(org_df)
else:
    print(f"No data found for {domain_to_view}")

# Load cybersecurity assessments
cyber_file = output_dir / domain_to_view.lower().replace(" ", "_") / f"organization_cyber_{domain_to_view.lower().replace(' ', '_')}.xlsx"
if cyber_file.exists():
    cyber_df = pd.read_excel(cyber_file)
    print(f"\nCybersecurity assessments for {domain_to_view}:")
    display(cyber_df)
else:
    print(f"No cyber assessment data found for {domain_to_view}")
# Out:
# Organizations for Science & Technology:
#                                               question  error  \
# 0    What is the top-level state Organ (i.e., minis...    NaN
# 1    What is the top-level state Organ (i.e., minis...    NaN
# 2    What is the top-level state Organ (i.e., minis...    NaN
# 3    What is the top-level state Organ (i.e., minis...    NaN
# 4    What is the top-level state Organ (i.e., minis...    NaN
# ..                                                 ...    ...
# 188  What is the top-level state Organ (i.e., minis...    NaN
# 189  What is the top-level state Organ (i.e., minis...    NaN
# 190  What is the top-level state Organ (i.e., minis...    NaN
# 191  What is the top-level state Organ (i.e., minis...    NaN
# 192  What is the top-level state Organ (i.e., minis...    NaN
#
#                    domain                           country  \
# 0    SCIENCE & TECHNOLOGY                           BELARUS
# 1    SCIENCE & TECHNOLOGY                           DENMARK
# 2    SCIENCE & TECHNOLOGY                            MEXICO
# 3    SCIENCE & TECHNOLOGY                            RUSSIA
# 4    SCIENCE & TECHNOLOGY                         INDONESIA
# ..                    ...                               ...
# 188  SCIENCE & TECHNOLOGY                           ROMANIA
# 189  SCIENCE & TECHNOLOGY                          THAILAND
# 190  SCIENCE & TECHNOLOGY  DEMOCRATIC REPUBLIC OF THE CONGO
# 191  SCIENCE & TECHNOLOGY                       TIMOR-LESTE
# 192  SCIENCE & TECHNOLOGY                         MAURITIUS
#
#                                      organization_name            confidence
# 0    State Committee on Science and Technology of t...  ConfidenceLevel.HIGH
# 1             Ministry of Higher Education and Science  ConfidenceLevel.HIGH
# 2    Secretariat of Science, Humanities, Technology...  ConfidenceLevel.HIGH
# 3    Ministry of Science and Higher Education of th...  ConfidenceLevel.HIGH
# 4    Ministry of Higher Education, Science, and Tec...  ConfidenceLevel.HIGH
# ..                                                 ...                   ...
# 188  Ministry of Research, Innovation and Digitaliz...  ConfidenceLevel.HIGH
# 189  Ministry of Higher Education, Science, Researc...  ConfidenceLevel.HIGH
# 190  Ministry of Scientific Research and Technologi...  ConfidenceLevel.HIGH
# 191  Ministry of Higher Education, Science and Culture  ConfidenceLevel.HIGH
# 192  Ministry of Education, Tertiary Education, Sci...  ConfidenceLevel.HIGH
#
# [193 rows x 6 columns]
# Cybersecurity assessments for Science & Technology:
#                                               question  error  \
# 0    Is the Ministry of Business, Innovation and Em...    NaN
# 1    Is the Ministry of Education, Culture and Scie...    NaN
# 2    Is the NONE in LIBERIA responsible for cyberse...    NaN
# 3    Is the Ministry of Higher Education, Research,...    NaN
# 4    Is the Ministry of Telecommunications, Science...    NaN
# ..                                                 ...    ...
# 188  Is the Ministry of Higher Education and Scient...    NaN
# 189  Is the Ministry of Education, Science and Inno...    NaN
# 190  Is the Ministry of Science, Technology and Spa...    NaN
# 191  Is the Ministry of Higher Education and Scient...    NaN
# 192  Is the Ministère de l'Enseignement Supérieur e...    NaN
#
#                                   organization_country  \
# 0    Ministry of Business, Innovation and Employmen...
# 1    Ministry of Education, Culture and Science of ...
# 2                                      NONE in LIBERIA
# 3    Ministry of Higher Education, Research, Scienc...
# 4    Ministry of Telecommunications, Science, Techn...
# ..                                                 ...
# 188  Ministry of Higher Education and Scientific Re...
# 189  Ministry of Education, Science and Innovation ...
# 190  Ministry of Science, Technology and Space in I...
# 191  Ministry of Higher Education and Scientific Re...
# 192  Ministère de l'Enseignement Supérieur et de la...
#
#                                           organization  \
# 0      Ministry of Business, Innovation and Employment
# 1    Ministry of Education, Culture and Science of ...
# 2                                                 NONE
# 3    Ministry of Higher Education, Research, Scienc...
# 4    Ministry of Telecommunications, Science, Techn...
# ..                                                 ...
# 188  Ministry of Higher Education and Scientific Re...
# 189      Ministry of Education, Science and Innovation
# 190          Ministry of Science, Technology and Space
# 191  Ministry of Higher Education and Scientific Re...
# 192  Ministère de l'Enseignement Supérieur et de la...
#
#                               country      responsibility_level  \
# 0                         New Zealand  ResponsibilityLevel.HIGH
# 1                            Mongolia   ResponsibilityLevel.LOW
# 2                             Liberia  ResponsibilityLevel.NONE
# 3                    Papua New Guinea   ResponsibilityLevel.LOW
# 4    Saint Vincent and the Grenadines   ResponsibilityLevel.LOW
# ..                                ...                       ...
# 188                           Algeria  ResponsibilityLevel.HIGH
# 189                          Portugal   ResponsibilityLevel.LOW
# 190                            Israel   ResponsibilityLevel.LOW
# 191                             YEMEN   ResponsibilityLevel.LOW
# 192                        Madagascar   ResponsibilityLevel.LOW
#
#                                            explanation  \
# 0    The Ministry of Business, Innovation and Emplo...
# 1    The Ministry of Education, Culture and Science...
# 2    There is no governmental organization named 'N...
# 3    The Ministry of Higher Education, Research, Sc...
# 4    There is no direct evidence from the available...
# ..                                                 ...
# 188  The Ministry of Higher Education and Scientifi...
# 189  The Ministry of Education, Science and Innovat...
# 190  The Ministry of Science, Technology and Space ...
# 191  The Ministry of Higher Education and Scientifi...
# 192  The available evidence does not indicate that ...
#
#                  confidence                                 enriched_citations
# 0      ConfidenceLevel.HIGH  [{'url': 'https://www.dpmc.govt.nz/sites/defau...
# 1      ConfidenceLevel.HIGH  [{'url': 'https://education-profiles.org/easte...
# 2      ConfidenceLevel.HIGH  [{'url': 'https://thegfce.org/member-and-partn...
# 3      ConfidenceLevel.HIGH  [{'url': 'https://pacificislands.ai/png-takes-...
# 4    ConfidenceLevel.MEDIUM  [{'url': 'https://caricom.org/tag/cyber-securi...
# ..                      ...                                                ...
# 188    ConfidenceLevel.HIGH  [{'url': 'https://www.trade.gov/country-commer...
# 189    ConfidenceLevel.HIGH  [{'url': 'https://ccdcoe.org/uploads/2018/10/P...
# 190    ConfidenceLevel.HIGH  [{'url': 'https://css.ethz.ch/content/dam/ethz...
# 191    ConfidenceLevel.HIGH  [{'url': 'https://ncsi.ega.ee/country/ye_2022/...
# 192    ConfidenceLevel.HIGH  [{'url': 'https://cybilportal.org/projects/mad...
#
# [193 rows x 9 columns]

# %% [markdown]
# ## Summary Statistics
#
# Get a summary of all processed domains:

# %%
summary = []
for domain in domains_to_process:
    domain_slug = domain.lower().replace(" ", "_").replace("/", "_")
    org_file = output_dir / domain_slug / f"organization_names_{domain_slug}.csv"
    cyber_file = output_dir / domain_slug / f"organization_cyber_{domain_slug}.xlsx"
    
    if org_file.exists() and cyber_file.exists():
        org_df = pd.read_csv(org_file)
        cyber_df = pd.read_excel(cyber_file)
        summary.append({
            "Domain": domain,
            "Organizations": len(org_df),
            "Assessments": len(cyber_df),
            "Status": "✓ Complete"
        })
    else:
        summary.append({
            "Domain": domain,
            "Organizations": 0,
            "Assessments": 0,
            "Status": "✗ Incomplete"
        })

summary_df = pd.DataFrame(summary)
display(summary_df)
# Out:
#                  Domain  Organizations  Assessments      Status
# 0  Science & Technology            193          193  ✓ Complete
# 1       Foreign Affairs            193          193  ✓ Complete
# 2               Defense            193          193  ✓ Complete
# 3             Education            193          193  ✓ Complete
